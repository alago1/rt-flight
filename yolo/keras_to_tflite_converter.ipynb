# %% [markdown]
# ### This notebook addresses how to convert a model from keras .h5 to tflite and optionally edge-tpu within the context of YoloV3
#
# If you need support for converting darknet to keras, please refer to [this github](https://github.com/qqwweee/keras-yolo3).

# %%
import os
import tensorflow as tf

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

model = tf.keras.models.load_model('yolov3-aerial.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# ### Though keras models tend to support dynamic shapes, many edge devices do not. So we convert the model to a static shape and preprocess the images appropriately before invoking the model during inference.

# %%
model_config = model.get_config()

# %%
model_config['layers'][0]['config']['batch_input_shape'] = (1, 416, 416, 3)

# %% [markdown]
# ### Edge-TPU does not support LeakyReLU activation layers. However, during inference we can replace them with the supported PReLU.
#
# Note, PReLU is not a suitable replacement during the training stage so do not train in the Edge-TPU.

# %%
# edge-tpu only

for layer in model_config['layers']:
    if layer['class_name'] != 'LeakyReLU':
        continue

    name_index = layer['config']['name'][len('leaky_re_lu_'):]

    layer['class_name'] = 'PReLU'
    layer['config'] = {
        'name': f'p_re_lu_{name_index}',
        'alpha_initializer': {'class_name': 'Constant', 'config': {'value': layer['config']['alpha']}},
        'alpha_regularizer': None,
        'alpha_constraint': None,
        'shared_axes': [1, 2]  # required but not sure if it's correct
    }

# %%
new_model = model.__class__.from_config(model_config)

# %%
# copy over all weights except for the PReLU layers

weights = [layer.get_weights() for layer in model.layers[1:]]
for layer, weight in zip(new_model.layers[1:], weights):
    if layer.name.startswith('p_re_lu_'):
        continue

    layer.set_weights(weight)

# %% [markdown]
# ### Compiling the model should automatically calculate the shapes of the internal layers now that we defined the shape of the output layer

# %%
new_model.compile()

# %%
new_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image_input (InputLayer)       [(1, 416, 416, 3)]   0           []
#
#  conv2d (Conv2D)                (1, 416, 416, 32)    864         ['image_input[0][0]']
#
#  batch_normalization (BatchNorm  (1, 416, 416, 32)   128         ['conv2d[0][0]']
#  alization)
#
#  p_re_lu_ (PReLU)               (1, 416, 416, 32)    32          ['batch_normalization[0][0]']
#
#  zero_padding2d (ZeroPadding2D)  (1, 417, 417, 32)   0           ['p_re_lu_[0][0]']
#
#  conv2d_1 (Conv2D)              (1, 208, 208, 64)    18432       ['zero_padding2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (1, 208, 208, 64)   256         ['conv2d_1[0][0]']
#  rmalization)
#
#  p_re_lu_1 (PReLU)              (1, 208, 208, 64)    64          ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (1, 208, 208, 32)    2048        ['p_re_lu_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (1, 208, 208, 32)   128         ['conv2d_2[0][0]']
#  rmalization)
#
#  p_re_lu_2 (PReLU)              (1, 208, 208, 32)    32          ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (1, 208, 208, 64)    18432       ['p_re_lu_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (1, 208, 208, 64)   256         ['conv2d_3[0][0]']
#  rmalization)
#
#  p_re_lu_3 (PReLU)              (1, 208, 208, 64)    64          ['batch_normalization_3[0][0]']
#
#  add (Add)                      (1, 208, 208, 64)    0           ['p_re_lu_1[0][0]',
#                                                                   'p_re_lu_3[0][0]']
#
#  zero_padding2d_1 (ZeroPadding2  (1, 209, 209, 64)   0           ['add[0][0]']
#  D)
#
#  conv2d_4 (Conv2D)              (1, 104, 104, 128)   73728       ['zero_padding2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (1, 104, 104, 128)  512         ['conv2d_4[0][0]']
#  rmalization)
#
#  p_re_lu_4 (PReLU)              (1, 104, 104, 128)   128         ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (1, 104, 104, 64)    8192        ['p_re_lu_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (1, 104, 104, 64)   256         ['conv2d_5[0][0]']
#  rmalization)
#
#  p_re_lu_5 (PReLU)              (1, 104, 104, 64)    64          ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (1, 104, 104, 128)   73728       ['p_re_lu_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (1, 104, 104, 128)  512         ['conv2d_6[0][0]']
#  rmalization)
#
#  p_re_lu_6 (PReLU)              (1, 104, 104, 128)   128         ['batch_normalization_6[0][0]']
#
#  add_1 (Add)                    (1, 104, 104, 128)   0           ['p_re_lu_4[0][0]',
#                                                                   'p_re_lu_6[0][0]']
#
#  conv2d_7 (Conv2D)              (1, 104, 104, 64)    8192        ['add_1[0][0]']
#
#  batch_normalization_7 (BatchNo  (1, 104, 104, 64)   256         ['conv2d_7[0][0]']
#  rmalization)
#
#  p_re_lu_7 (PReLU)              (1, 104, 104, 64)    64          ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (1, 104, 104, 128)   73728       ['p_re_lu_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (1, 104, 104, 128)  512         ['conv2d_8[0][0]']
#  rmalization)
#
#  p_re_lu_8 (PReLU)              (1, 104, 104, 128)   128         ['batch_normalization_8[0][0]']
#
#  add_2 (Add)                    (1, 104, 104, 128)   0           ['add_1[0][0]',
#                                                                   'p_re_lu_8[0][0]']
#
#  zero_padding2d_2 (ZeroPadding2  (1, 105, 105, 128)  0           ['add_2[0][0]']
#  D)
#
#  conv2d_9 (Conv2D)              (1, 52, 52, 256)     294912      ['zero_padding2d_2[0][0]']
#
#  batch_normalization_9 (BatchNo  (1, 52, 52, 256)    1024        ['conv2d_9[0][0]']
#  rmalization)
#
#  p_re_lu_9 (PReLU)              (1, 52, 52, 256)     256         ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (1, 52, 52, 128)     32768       ['p_re_lu_9[0][0]']
#
#  batch_normalization_10 (BatchN  (1, 52, 52, 128)    512         ['conv2d_10[0][0]']
#  ormalization)
#
#  p_re_lu_10 (PReLU)             (1, 52, 52, 128)     128         ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (1, 52, 52, 256)     294912      ['p_re_lu_10[0][0]']
#
#  batch_normalization_11 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_11[0][0]']
#  ormalization)
#
#  p_re_lu_11 (PReLU)             (1, 52, 52, 256)     256         ['batch_normalization_11[0][0]']
#
#  add_3 (Add)                    (1, 52, 52, 256)     0           ['p_re_lu_9[0][0]',
#                                                                   'p_re_lu_11[0][0]']
#
#  conv2d_12 (Conv2D)             (1, 52, 52, 128)     32768       ['add_3[0][0]']
#
#  batch_normalization_12 (BatchN  (1, 52, 52, 128)    512         ['conv2d_12[0][0]']
#  ormalization)
#
#  p_re_lu_12 (PReLU)             (1, 52, 52, 128)     128         ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (1, 52, 52, 256)     294912      ['p_re_lu_12[0][0]']
#
#  batch_normalization_13 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_13[0][0]']
#  ormalization)
#
#  p_re_lu_13 (PReLU)             (1, 52, 52, 256)     256         ['batch_normalization_13[0][0]']
#
#  add_4 (Add)                    (1, 52, 52, 256)     0           ['add_3[0][0]',
#                                                                   'p_re_lu_13[0][0]']
#
#  conv2d_14 (Conv2D)             (1, 52, 52, 128)     32768       ['add_4[0][0]']
#
#  batch_normalization_14 (BatchN  (1, 52, 52, 128)    512         ['conv2d_14[0][0]']
#  ormalization)
#
#  p_re_lu_14 (PReLU)             (1, 52, 52, 128)     128         ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (1, 52, 52, 256)     294912      ['p_re_lu_14[0][0]']
#
#  batch_normalization_15 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_15[0][0]']
#  ormalization)
#
#  p_re_lu_15 (PReLU)             (1, 52, 52, 256)     256         ['batch_normalization_15[0][0]']
#
#  add_5 (Add)                    (1, 52, 52, 256)     0           ['add_4[0][0]',
#                                                                   'p_re_lu_15[0][0]']
#
#  conv2d_16 (Conv2D)             (1, 52, 52, 128)     32768       ['add_5[0][0]']
#
#  batch_normalization_16 (BatchN  (1, 52, 52, 128)    512         ['conv2d_16[0][0]']
#  ormalization)
#
#  p_re_lu_16 (PReLU)             (1, 52, 52, 128)     128         ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (1, 52, 52, 256)     294912      ['p_re_lu_16[0][0]']
#
#  batch_normalization_17 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_17[0][0]']
#  ormalization)
#
#  p_re_lu_17 (PReLU)             (1, 52, 52, 256)     256         ['batch_normalization_17[0][0]']
#
#  add_6 (Add)                    (1, 52, 52, 256)     0           ['add_5[0][0]',
#                                                                   'p_re_lu_17[0][0]']
#
#  conv2d_18 (Conv2D)             (1, 52, 52, 128)     32768       ['add_6[0][0]']
#
#  batch_normalization_18 (BatchN  (1, 52, 52, 128)    512         ['conv2d_18[0][0]']
#  ormalization)
#
#  p_re_lu_18 (PReLU)             (1, 52, 52, 128)     128         ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (1, 52, 52, 256)     294912      ['p_re_lu_18[0][0]']
#
#  batch_normalization_19 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_19[0][0]']
#  ormalization)
#
#  p_re_lu_19 (PReLU)             (1, 52, 52, 256)     256         ['batch_normalization_19[0][0]']
#
#  add_7 (Add)                    (1, 52, 52, 256)     0           ['add_6[0][0]',
#                                                                   'p_re_lu_19[0][0]']
#
#  conv2d_20 (Conv2D)             (1, 52, 52, 128)     32768       ['add_7[0][0]']
#
#  batch_normalization_20 (BatchN  (1, 52, 52, 128)    512         ['conv2d_20[0][0]']
#  ormalization)
#
#  p_re_lu_20 (PReLU)             (1, 52, 52, 128)     128         ['batch_normalization_20[0][0]']
#
#  conv2d_21 (Conv2D)             (1, 52, 52, 256)     294912      ['p_re_lu_20[0][0]']
#
#  batch_normalization_21 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_21[0][0]']
#  ormalization)
#
#  p_re_lu_21 (PReLU)             (1, 52, 52, 256)     256         ['batch_normalization_21[0][0]']
#
#  add_8 (Add)                    (1, 52, 52, 256)     0           ['add_7[0][0]',
#                                                                   'p_re_lu_21[0][0]']
#
#  conv2d_22 (Conv2D)             (1, 52, 52, 128)     32768       ['add_8[0][0]']
#
#  batch_normalization_22 (BatchN  (1, 52, 52, 128)    512         ['conv2d_22[0][0]']
#  ormalization)
#
#  p_re_lu_22 (PReLU)             (1, 52, 52, 128)     128         ['batch_normalization_22[0][0]']
#
#  conv2d_23 (Conv2D)             (1, 52, 52, 256)     294912      ['p_re_lu_22[0][0]']
#
#  batch_normalization_23 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_23[0][0]']
#  ormalization)
#
#  p_re_lu_23 (PReLU)             (1, 52, 52, 256)     256         ['batch_normalization_23[0][0]']
#
#  add_9 (Add)                    (1, 52, 52, 256)     0           ['add_8[0][0]',
#                                                                   'p_re_lu_23[0][0]']
#
#  conv2d_24 (Conv2D)             (1, 52, 52, 128)     32768       ['add_9[0][0]']
#
#  batch_normalization_24 (BatchN  (1, 52, 52, 128)    512         ['conv2d_24[0][0]']
#  ormalization)
#
#  p_re_lu_24 (PReLU)             (1, 52, 52, 128)     128         ['batch_normalization_24[0][0]']
#
#  conv2d_25 (Conv2D)             (1, 52, 52, 256)     294912      ['p_re_lu_24[0][0]']
#
#  batch_normalization_25 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_25[0][0]']
#  ormalization)
#
#  p_re_lu_25 (PReLU)             (1, 52, 52, 256)     256         ['batch_normalization_25[0][0]']
#
#  add_10 (Add)                   (1, 52, 52, 256)     0           ['add_9[0][0]',
#                                                                   'p_re_lu_25[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (1, 53, 53, 256)    0           ['add_10[0][0]']
#  D)
#
#  conv2d_26 (Conv2D)             (1, 26, 26, 512)     1179648     ['zero_padding2d_3[0][0]']
#
#  batch_normalization_26 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_26[0][0]']
#  ormalization)
#
#  p_re_lu_26 (PReLU)             (1, 26, 26, 512)     512         ['batch_normalization_26[0][0]']
#
#  conv2d_27 (Conv2D)             (1, 26, 26, 256)     131072      ['p_re_lu_26[0][0]']
#
#  batch_normalization_27 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_27[0][0]']
#  ormalization)
#
#  p_re_lu_27 (PReLU)             (1, 26, 26, 256)     256         ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (1, 26, 26, 512)     1179648     ['p_re_lu_27[0][0]']
#
#  batch_normalization_28 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_28[0][0]']
#  ormalization)
#
#  p_re_lu_28 (PReLU)             (1, 26, 26, 512)     512         ['batch_normalization_28[0][0]']
#
#  add_11 (Add)                   (1, 26, 26, 512)     0           ['p_re_lu_26[0][0]',
#                                                                   'p_re_lu_28[0][0]']
#
#  conv2d_29 (Conv2D)             (1, 26, 26, 256)     131072      ['add_11[0][0]']
#
#  batch_normalization_29 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_29[0][0]']
#  ormalization)
#
#  p_re_lu_29 (PReLU)             (1, 26, 26, 256)     256         ['batch_normalization_29[0][0]']
#
#  conv2d_30 (Conv2D)             (1, 26, 26, 512)     1179648     ['p_re_lu_29[0][0]']
#
#  batch_normalization_30 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_30[0][0]']
#  ormalization)
#
#  p_re_lu_30 (PReLU)             (1, 26, 26, 512)     512         ['batch_normalization_30[0][0]']
#
#  add_12 (Add)                   (1, 26, 26, 512)     0           ['add_11[0][0]',
#                                                                   'p_re_lu_30[0][0]']
#
#  conv2d_31 (Conv2D)             (1, 26, 26, 256)     131072      ['add_12[0][0]']
#
#  batch_normalization_31 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_31[0][0]']
#  ormalization)
#
#  p_re_lu_31 (PReLU)             (1, 26, 26, 256)     256         ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (1, 26, 26, 512)     1179648     ['p_re_lu_31[0][0]']
#
#  batch_normalization_32 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_32[0][0]']
#  ormalization)
#
#  p_re_lu_32 (PReLU)             (1, 26, 26, 512)     512         ['batch_normalization_32[0][0]']
#
#  add_13 (Add)                   (1, 26, 26, 512)     0           ['add_12[0][0]',
#                                                                   'p_re_lu_32[0][0]']
#
#  conv2d_33 (Conv2D)             (1, 26, 26, 256)     131072      ['add_13[0][0]']
#
#  batch_normalization_33 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_33[0][0]']
#  ormalization)
#
#  p_re_lu_33 (PReLU)             (1, 26, 26, 256)     256         ['batch_normalization_33[0][0]']
#
#  conv2d_34 (Conv2D)             (1, 26, 26, 512)     1179648     ['p_re_lu_33[0][0]']
#
#  batch_normalization_34 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_34[0][0]']
#  ormalization)
#
#  p_re_lu_34 (PReLU)             (1, 26, 26, 512)     512         ['batch_normalization_34[0][0]']
#
#  add_14 (Add)                   (1, 26, 26, 512)     0           ['add_13[0][0]',
#                                                                   'p_re_lu_34[0][0]']
#
#  conv2d_35 (Conv2D)             (1, 26, 26, 256)     131072      ['add_14[0][0]']
#
#  batch_normalization_35 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_35[0][0]']
#  ormalization)
#
#  p_re_lu_35 (PReLU)             (1, 26, 26, 256)     256         ['batch_normalization_35[0][0]']
#
#  conv2d_36 (Conv2D)             (1, 26, 26, 512)     1179648     ['p_re_lu_35[0][0]']
#
#  batch_normalization_36 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_36[0][0]']
#  ormalization)
#
#  p_re_lu_36 (PReLU)             (1, 26, 26, 512)     512         ['batch_normalization_36[0][0]']
#
#  add_15 (Add)                   (1, 26, 26, 512)     0           ['add_14[0][0]',
#                                                                   'p_re_lu_36[0][0]']
#
#  conv2d_37 (Conv2D)             (1, 26, 26, 256)     131072      ['add_15[0][0]']
#
#  batch_normalization_37 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_37[0][0]']
#  ormalization)
#
#  p_re_lu_37 (PReLU)             (1, 26, 26, 256)     256         ['batch_normalization_37[0][0]']
#
#  conv2d_38 (Conv2D)             (1, 26, 26, 512)     1179648     ['p_re_lu_37[0][0]']
#
#  batch_normalization_38 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_38[0][0]']
#  ormalization)
#
#  p_re_lu_38 (PReLU)             (1, 26, 26, 512)     512         ['batch_normalization_38[0][0]']
#
#  add_16 (Add)                   (1, 26, 26, 512)     0           ['add_15[0][0]',
#                                                                   'p_re_lu_38[0][0]']
#
#  conv2d_39 (Conv2D)             (1, 26, 26, 256)     131072      ['add_16[0][0]']
#
#  batch_normalization_39 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_39[0][0]']
#  ormalization)
#
#  p_re_lu_39 (PReLU)             (1, 26, 26, 256)     256         ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (1, 26, 26, 512)     1179648     ['p_re_lu_39[0][0]']
#
#  batch_normalization_40 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_40[0][0]']
#  ormalization)
#
#  p_re_lu_40 (PReLU)             (1, 26, 26, 512)     512         ['batch_normalization_40[0][0]']
#
#  add_17 (Add)                   (1, 26, 26, 512)     0           ['add_16[0][0]',
#                                                                   'p_re_lu_40[0][0]']
#
#  conv2d_41 (Conv2D)             (1, 26, 26, 256)     131072      ['add_17[0][0]']
#
#  batch_normalization_41 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_41[0][0]']
#  ormalization)
#
#  p_re_lu_41 (PReLU)             (1, 26, 26, 256)     256         ['batch_normalization_41[0][0]']
#
#  conv2d_42 (Conv2D)             (1, 26, 26, 512)     1179648     ['p_re_lu_41[0][0]']
#
#  batch_normalization_42 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_42[0][0]']
#  ormalization)
#
#  p_re_lu_42 (PReLU)             (1, 26, 26, 512)     512         ['batch_normalization_42[0][0]']
#
#  add_18 (Add)                   (1, 26, 26, 512)     0           ['add_17[0][0]',
#                                                                   'p_re_lu_42[0][0]']
#
#  zero_padding2d_4 (ZeroPadding2  (1, 27, 27, 512)    0           ['add_18[0][0]']
#  D)
#
#  conv2d_43 (Conv2D)             (1, 13, 13, 1024)    4718592     ['zero_padding2d_4[0][0]']
#
#  batch_normalization_43 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_43[0][0]']
#  ormalization)
#
#  p_re_lu_43 (PReLU)             (1, 13, 13, 1024)    1024        ['batch_normalization_43[0][0]']
#
#  conv2d_44 (Conv2D)             (1, 13, 13, 512)     524288      ['p_re_lu_43[0][0]']
#
#  batch_normalization_44 (BatchN  (1, 13, 13, 512)    2048        ['conv2d_44[0][0]']
#  ormalization)
#
#  p_re_lu_44 (PReLU)             (1, 13, 13, 512)     512         ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (1, 13, 13, 1024)    4718592     ['p_re_lu_44[0][0]']
#
#  batch_normalization_45 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_45[0][0]']
#  ormalization)
#
#  p_re_lu_45 (PReLU)             (1, 13, 13, 1024)    1024        ['batch_normalization_45[0][0]']
#
#  add_19 (Add)                   (1, 13, 13, 1024)    0           ['p_re_lu_43[0][0]',
#                                                                   'p_re_lu_45[0][0]']
#
#  conv2d_46 (Conv2D)             (1, 13, 13, 512)     524288      ['add_19[0][0]']
#
#  batch_normalization_46 (BatchN  (1, 13, 13, 512)    2048        ['conv2d_46[0][0]']
#  ormalization)
#
#  p_re_lu_46 (PReLU)             (1, 13, 13, 512)     512         ['batch_normalization_46[0][0]']
#
#  conv2d_47 (Conv2D)             (1, 13, 13, 1024)    4718592     ['p_re_lu_46[0][0]']
#
#  batch_normalization_47 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_47[0][0]']
#  ormalization)
#
#  p_re_lu_47 (PReLU)             (1, 13, 13, 1024)    1024        ['batch_normalization_47[0][0]']
#
#  add_20 (Add)                   (1, 13, 13, 1024)    0           ['add_19[0][0]',
#                                                                   'p_re_lu_47[0][0]']
#
#  conv2d_48 (Conv2D)             (1, 13, 13, 512)     524288      ['add_20[0][0]']
#
#  batch_normalization_48 (BatchN  (1, 13, 13, 512)    2048        ['conv2d_48[0][0]']
#  ormalization)
#
#  p_re_lu_48 (PReLU)             (1, 13, 13, 512)     512         ['batch_normalization_48[0][0]']
#
#  conv2d_49 (Conv2D)             (1, 13, 13, 1024)    4718592     ['p_re_lu_48[0][0]']
#
#  batch_normalization_49 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_49[0][0]']
#  ormalization)
#
#  p_re_lu_49 (PReLU)             (1, 13, 13, 1024)    1024        ['batch_normalization_49[0][0]']
#
#  add_21 (Add)                   (1, 13, 13, 1024)    0           ['add_20[0][0]',
#                                                                   'p_re_lu_49[0][0]']
#
#  conv2d_50 (Conv2D)             (1, 13, 13, 512)     524288      ['add_21[0][0]']
#
#  batch_normalization_50 (BatchN  (1, 13, 13, 512)    2048        ['conv2d_50[0][0]']
#  ormalization)
#
#  p_re_lu_50 (PReLU)             (1, 13, 13, 512)     512         ['batch_normalization_50[0][0]']
#
#  conv2d_51 (Conv2D)             (1, 13, 13, 1024)    4718592     ['p_re_lu_50[0][0]']
#
#  batch_normalization_51 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_51[0][0]']
#  ormalization)
#
#  p_re_lu_51 (PReLU)             (1, 13, 13, 1024)    1024        ['batch_normalization_51[0][0]']
#
#  add_22 (Add)                   (1, 13, 13, 1024)    0           ['add_21[0][0]',
#                                                                   'p_re_lu_51[0][0]']
#
#  conv2d_52 (Conv2D)             (1, 13, 13, 512)     524288      ['add_22[0][0]']
#
#  batch_normalization_52 (BatchN  (1, 13, 13, 512)    2048        ['conv2d_52[0][0]']
#  ormalization)
#
#  p_re_lu_52 (PReLU)             (1, 13, 13, 512)     512         ['batch_normalization_52[0][0]']
#
#  conv2d_53 (Conv2D)             (1, 13, 13, 1024)    4718592     ['p_re_lu_52[0][0]']
#
#  batch_normalization_53 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_53[0][0]']
#  ormalization)
#
#  p_re_lu_53 (PReLU)             (1, 13, 13, 1024)    1024        ['batch_normalization_53[0][0]']
#
#  conv2d_54 (Conv2D)             (1, 13, 13, 512)     524288      ['p_re_lu_53[0][0]']
#
#  batch_normalization_54 (BatchN  (1, 13, 13, 512)    2048        ['conv2d_54[0][0]']
#  ormalization)
#
#  p_re_lu_54 (PReLU)             (1, 13, 13, 512)     512         ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (1, 13, 13, 1024)    4718592     ['p_re_lu_54[0][0]']
#
#  batch_normalization_55 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_55[0][0]']
#  ormalization)
#
#  p_re_lu_55 (PReLU)             (1, 13, 13, 1024)    1024        ['batch_normalization_55[0][0]']
#
#  conv2d_56 (Conv2D)             (1, 13, 13, 512)     524288      ['p_re_lu_55[0][0]']
#
#  batch_normalization_56 (BatchN  (1, 13, 13, 512)    2048        ['conv2d_56[0][0]']
#  ormalization)
#
#  p_re_lu_56 (PReLU)             (1, 13, 13, 512)     512         ['batch_normalization_56[0][0]']
#
#  conv2d_59 (Conv2D)             (1, 13, 13, 256)     131072      ['p_re_lu_56[0][0]']
#
#  batch_normalization_58 (BatchN  (1, 13, 13, 256)    1024        ['conv2d_59[0][0]']
#  ormalization)
#
#  p_re_lu_58 (PReLU)             (1, 13, 13, 256)     256         ['batch_normalization_58[0][0]']
#
#  up_sampling2d (UpSampling2D)   (1, 26, 26, 256)     0           ['p_re_lu_58[0][0]']
#
#  concatenate (Concatenate)      (1, 26, 26, 768)     0           ['up_sampling2d[0][0]',
#                                                                   'add_18[0][0]']
#
#  conv2d_60 (Conv2D)             (1, 26, 26, 256)     196608      ['concatenate[0][0]']
#
#  batch_normalization_59 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_60[0][0]']
#  ormalization)
#
#  p_re_lu_59 (PReLU)             (1, 26, 26, 256)     256         ['batch_normalization_59[0][0]']
#
#  conv2d_61 (Conv2D)             (1, 26, 26, 512)     1179648     ['p_re_lu_59[0][0]']
#
#  batch_normalization_60 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_61[0][0]']
#  ormalization)
#
#  p_re_lu_60 (PReLU)             (1, 26, 26, 512)     512         ['batch_normalization_60[0][0]']
#
#  conv2d_62 (Conv2D)             (1, 26, 26, 256)     131072      ['p_re_lu_60[0][0]']
#
#  batch_normalization_61 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_62[0][0]']
#  ormalization)
#
#  p_re_lu_61 (PReLU)             (1, 26, 26, 256)     256         ['batch_normalization_61[0][0]']
#
#  conv2d_63 (Conv2D)             (1, 26, 26, 512)     1179648     ['p_re_lu_61[0][0]']
#
#  batch_normalization_62 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_63[0][0]']
#  ormalization)
#
#  p_re_lu_62 (PReLU)             (1, 26, 26, 512)     512         ['batch_normalization_62[0][0]']
#
#  conv2d_64 (Conv2D)             (1, 26, 26, 256)     131072      ['p_re_lu_62[0][0]']
#
#  batch_normalization_63 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_64[0][0]']
#  ormalization)
#
#  p_re_lu_63 (PReLU)             (1, 26, 26, 256)     256         ['batch_normalization_63[0][0]']
#
#  conv2d_67 (Conv2D)             (1, 26, 26, 128)     32768       ['p_re_lu_63[0][0]']
#
#  batch_normalization_65 (BatchN  (1, 26, 26, 128)    512         ['conv2d_67[0][0]']
#  ormalization)
#
#  p_re_lu_65 (PReLU)             (1, 26, 26, 128)     128         ['batch_normalization_65[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (1, 52, 52, 128)    0           ['p_re_lu_65[0][0]']
#
#  concatenate_1 (Concatenate)    (1, 52, 52, 384)     0           ['up_sampling2d_1[0][0]',
#                                                                   'add_10[0][0]']
#
#  conv2d_68 (Conv2D)             (1, 52, 52, 128)     49152       ['concatenate_1[0][0]']
#
#  batch_normalization_66 (BatchN  (1, 52, 52, 128)    512         ['conv2d_68[0][0]']
#  ormalization)
#
#  p_re_lu_66 (PReLU)             (1, 52, 52, 128)     128         ['batch_normalization_66[0][0]']
#
#  conv2d_69 (Conv2D)             (1, 52, 52, 256)     294912      ['p_re_lu_66[0][0]']
#
#  batch_normalization_67 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_69[0][0]']
#  ormalization)
#
#  p_re_lu_67 (PReLU)             (1, 52, 52, 256)     256         ['batch_normalization_67[0][0]']
#
#  conv2d_70 (Conv2D)             (1, 52, 52, 128)     32768       ['p_re_lu_67[0][0]']
#
#  batch_normalization_68 (BatchN  (1, 52, 52, 128)    512         ['conv2d_70[0][0]']
#  ormalization)
#
#  p_re_lu_68 (PReLU)             (1, 52, 52, 128)     128         ['batch_normalization_68[0][0]']
#
#  conv2d_71 (Conv2D)             (1, 52, 52, 256)     294912      ['p_re_lu_68[0][0]']
#
#  batch_normalization_69 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_71[0][0]']
#  ormalization)
#
#  p_re_lu_69 (PReLU)             (1, 52, 52, 256)     256         ['batch_normalization_69[0][0]']
#
#  conv2d_72 (Conv2D)             (1, 52, 52, 128)     32768       ['p_re_lu_69[0][0]']
#
#  batch_normalization_70 (BatchN  (1, 52, 52, 128)    512         ['conv2d_72[0][0]']
#  ormalization)
#
#  p_re_lu_70 (PReLU)             (1, 52, 52, 128)     128         ['batch_normalization_70[0][0]']
#
#  conv2d_57 (Conv2D)             (1, 13, 13, 1024)    4718592     ['p_re_lu_56[0][0]']
#
#  conv2d_65 (Conv2D)             (1, 26, 26, 512)     1179648     ['p_re_lu_63[0][0]']
#
#  conv2d_73 (Conv2D)             (1, 52, 52, 256)     294912      ['p_re_lu_70[0][0]']
#
#  batch_normalization_57 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_57[0][0]']
#  ormalization)
#
#  batch_normalization_64 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_65[0][0]']
#  ormalization)
#
#  batch_normalization_71 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_73[0][0]']
#  ormalization)
#
#  p_re_lu_57 (PReLU)             (1, 13, 13, 1024)    1024        ['batch_normalization_57[0][0]']
#
#  p_re_lu_64 (PReLU)             (1, 26, 26, 512)     512         ['batch_normalization_64[0][0]']
#
#  p_re_lu_71 (PReLU)             (1, 52, 52, 256)     256         ['batch_normalization_71[0][0]']
#
#  conv2d_58 (Conv2D)             (1, 13, 13, 75)      76875       ['p_re_lu_57[0][0]']
#
#  conv2d_66 (Conv2D)             (1, 26, 26, 75)      38475       ['p_re_lu_64[0][0]']
#
#  conv2d_74 (Conv2D)             (1, 52, 52, 75)      19275       ['p_re_lu_71[0][0]']
#
# ==================================================================================================
# Total params: 61,704,961
# Trainable params: 61,652,353
# Non-trainable params: 52,608
# __________________________________________________________________________________________________

# %%
new_model.save('yolov3-aerial-compiled.h5')

# %% [markdown]
# ### Now that we have a properly formatted keras model, we will convert it to TFLite
#
# There are a few things to note here:
#  - We will perform quantization to reduce the size of the model and improve inference speed
#  - For CPUs we can use dynamic range quantization which is quite effective
#  - For Edge-TPU we must use full integer quantization which may involve some accuracy loss. We are also required to provide a representative dataset to calibrate the quantization process (whereas other devices this is optional and may improve accuracy)
#  - For GPUs we must use float16 quantization which is less memory efficient than the alternatives but still lowers memory usage by about 2 times
#
#  For a representative dataset, you need only a couple hundred examples. We will be using the dataset used to fine-tune our aerial model which contains about 130 images.

# %%
# clone repository
# !git clone git@github.com:jekhor/aerial-cars-dataset.git

# %%
def representative_dataset():
    folder_path = 'aerial-cars-dataset/'
    imgs = [img_path for img_path in os.listdir(folder_path) if img_path.endswith('.jpg') or img_path.endswith('.png')]

    for img_path in imgs:
        img = tf.keras.preprocessing.image.load_img(folder_path + img_path, target_size=(416, 416))
        img_array = tf.keras.preprocessing.image.img_to_array(img)
        img_array = tf.expand_dims(img_array, 0)
        img_array = img_array / 255.0
        yield [img_array]

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(new_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
# converter.target_spec.supported_types = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]  # this stil doesn't work for some reason
converter.inference_input_type = tf.uint8  # this is required for edge-tpu
converter.inference_output_type = tf.uint8  # this is required for edge-tpu

# %%
tflite_model = converter.convert()
# Out:
# 2023-05-17 19:18:59.032548: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 19:18:59.165127: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 19:19:05.190499: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 19:19:05.353505: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 76). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /tmp/tmp_oxizn4k/assets
# INFO:tensorflow:Assets written to: /tmp/tmp_oxizn4k/assets
# /home/allanlago/anaconda3/envs/tf-gpu/lib/python3.8/site-packages/tensorflow/lite/python/convert.py:789: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# 2023-05-17 19:19:16.348892: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# 2023-05-17 19:19:16.348930: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# 2023-05-17 19:19:16.349798: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: /tmp/tmp_oxizn4k
# 2023-05-17 19:19:16.369667: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
# 2023-05-17 19:19:16.369702: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: /tmp/tmp_oxizn4k
# 2023-05-17 19:19:16.440695: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:353] MLIR V1 optimization pass is not enabled
# 2023-05-17 19:19:16.466598: I tensorflow/cc/saved_model/loader.cc:231] Restoring SavedModel bundle.
# 2023-05-17 19:19:16.931070: I tensorflow/cc/saved_model/loader.cc:215] Running initialization op on SavedModel bundle at path: /tmp/tmp_oxizn4k
# 2023-05-17 19:19:17.071994: I tensorflow/cc/saved_model/loader.cc:314] SavedModel load for tags { serve }; Status: success: OK. Took 722211 microseconds.
# 2023-05-17 19:19:17.462195: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-05-17 19:19:18.384359: I tensorflow/compiler/mlir/lite/flatbuffer_export.cc:2116] Estimated count of arithmetic ops: 65.481 G  ops, equivalently 32.741 G  MACs
# fully_quantize: 0, inference_type: 6, input_inference_type: UINT8, output_inference_type: UINT8
# 2023-05-17 19:21:22.228584: I tensorflow/compiler/mlir/lite/flatbuffer_export.cc:2116] Estimated count of arithmetic ops: 65.481 G  ops, equivalently 32.741 G  MACs

# %%
with open('yolov3-aerial-int8.tflite', 'wb') as f:
  f.write(tflite_model)

# %%
# edge-tpu only
# !apt install edgetpu_compiler
# !edgetpu_compiler yolov3-aerial-int8.tflite
# Out:
# /usr/bin/zsh: /home/allanlago/anaconda3/envs/tf-gpu/lib/libtinfo.so.6: no version information available (required by /usr/bin/zsh)
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?
# /usr/bin/zsh: /home/allanlago/anaconda3/envs/tf-gpu/lib/libtinfo.so.6: no version information available (required by /usr/bin/zsh)
# /bin/bash: /home/allanlago/anaconda3/envs/tf-gpu/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Edge TPU Compiler version 16.0.384591198
# Started a compilation timeout timer of 180 seconds.
#
# Model compiled successfully in 5729 ms.
#
# Input model: yolov3-aerial-int8.tflite
# Input size: 59.49MiB
# Output model: yolov3-aerial-int8_edgetpu.tflite
# Output size: 60.06MiB
# On-chip memory used for caching model parameters: 6.84MiB
# On-chip memory remaining for caching model parameters: 5.75KiB
# Off-chip memory used for streaming uncached model parameters: 52.28MiB
# Number of Edge TPU subgraphs: 1
# Total number of operations: 183
# Operation log: yolov3-aerial-int8_edgetpu.log
# See the operation log file for individual operation details.
# Compilation child process completed within timeout period.
# Compilation succeeded!
