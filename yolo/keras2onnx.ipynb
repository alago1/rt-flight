# %% [markdown]
# ### This notebook addresses how to convert a model from keras .h5 to onnx within the context of YoloV3
#
# If you need support for converting darknet to keras, please refer to [this github](https://github.com/qqwweee/keras-yolo3).

# %% [markdown]
# We will the library [tf2onnx](https://github.com/onnx/tensorflow-onnx). If not installed, run the following command:

# %%
# !pip install -U tf2onnx

# %%
import tensorflow as tf
import tf2onnx
# Out:
# 2023-07-01 18:55:17.679382: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-07-01 18:55:17.716552: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-01 18:55:17.866815: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-01 18:55:17.867863: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-01 18:55:18.699791: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ##### Though keras models tend to support dynamic shapes, many edge devices do not. So we convert the model to a static shape and preprocess the images appropriately before invoking the model during inference.

# %%
model = tf.keras.models.load_model('yolov3-aerial.h5')
model_config = model.get_config()
model_config['layers'][0]['config']['batch_input_shape'] = (1, 416, 416, 3)
# Out:
# 2023-07-01 18:53:36.898327: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-07-01 18:53:37.008705: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
new_model = model.__class__.from_config(model_config)

# copy over all weights
weights = [layer.get_weights() for layer in model.layers[1:]]
for layer, weights in zip(new_model.layers[1:], weights):
    layer.set_weights(weights)

# %% [markdown]
# ##### Compiling the model should automatically calculate the shapes of the internal layers now that we defined the shape of the input layer

# %%
new_model.compile()

# %%
new_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image_input (InputLayer)       [(1, 416, 416, 3)]   0           []
#
#  conv2d (Conv2D)                (1, 416, 416, 32)    864         ['image_input[0][0]']
#
#  batch_normalization (BatchNorm  (1, 416, 416, 32)   128         ['conv2d[0][0]']
#  alization)
#
#  leaky_re_lu (LeakyReLU)        (1, 416, 416, 32)    0           ['batch_normalization[0][0]']
#
#  zero_padding2d (ZeroPadding2D)  (1, 417, 417, 32)   0           ['leaky_re_lu[0][0]']
#
#  conv2d_1 (Conv2D)              (1, 208, 208, 64)    18432       ['zero_padding2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (1, 208, 208, 64)   256         ['conv2d_1[0][0]']
#  rmalization)
#
#  leaky_re_lu_1 (LeakyReLU)      (1, 208, 208, 64)    0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (1, 208, 208, 32)    2048        ['leaky_re_lu_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (1, 208, 208, 32)   128         ['conv2d_2[0][0]']
#  rmalization)
#
#  leaky_re_lu_2 (LeakyReLU)      (1, 208, 208, 32)    0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (1, 208, 208, 64)    18432       ['leaky_re_lu_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (1, 208, 208, 64)   256         ['conv2d_3[0][0]']
#  rmalization)
#
#  leaky_re_lu_3 (LeakyReLU)      (1, 208, 208, 64)    0           ['batch_normalization_3[0][0]']
#
#  add (Add)                      (1, 208, 208, 64)    0           ['leaky_re_lu_1[0][0]',
#                                                                   'leaky_re_lu_3[0][0]']
#
#  zero_padding2d_1 (ZeroPadding2  (1, 209, 209, 64)   0           ['add[0][0]']
#  D)
#
#  conv2d_4 (Conv2D)              (1, 104, 104, 128)   73728       ['zero_padding2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (1, 104, 104, 128)  512         ['conv2d_4[0][0]']
#  rmalization)
#
#  leaky_re_lu_4 (LeakyReLU)      (1, 104, 104, 128)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (1, 104, 104, 64)    8192        ['leaky_re_lu_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (1, 104, 104, 64)   256         ['conv2d_5[0][0]']
#  rmalization)
#
#  leaky_re_lu_5 (LeakyReLU)      (1, 104, 104, 64)    0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (1, 104, 104, 128)   73728       ['leaky_re_lu_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (1, 104, 104, 128)  512         ['conv2d_6[0][0]']
#  rmalization)
#
#  leaky_re_lu_6 (LeakyReLU)      (1, 104, 104, 128)   0           ['batch_normalization_6[0][0]']
#
#  add_1 (Add)                    (1, 104, 104, 128)   0           ['leaky_re_lu_4[0][0]',
#                                                                   'leaky_re_lu_6[0][0]']
#
#  conv2d_7 (Conv2D)              (1, 104, 104, 64)    8192        ['add_1[0][0]']
#
#  batch_normalization_7 (BatchNo  (1, 104, 104, 64)   256         ['conv2d_7[0][0]']
#  rmalization)
#
#  leaky_re_lu_7 (LeakyReLU)      (1, 104, 104, 64)    0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (1, 104, 104, 128)   73728       ['leaky_re_lu_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (1, 104, 104, 128)  512         ['conv2d_8[0][0]']
#  rmalization)
#
#  leaky_re_lu_8 (LeakyReLU)      (1, 104, 104, 128)   0           ['batch_normalization_8[0][0]']
#
#  add_2 (Add)                    (1, 104, 104, 128)   0           ['add_1[0][0]',
#                                                                   'leaky_re_lu_8[0][0]']
#
#  zero_padding2d_2 (ZeroPadding2  (1, 105, 105, 128)  0           ['add_2[0][0]']
#  D)
#
#  conv2d_9 (Conv2D)              (1, 52, 52, 256)     294912      ['zero_padding2d_2[0][0]']
#
#  batch_normalization_9 (BatchNo  (1, 52, 52, 256)    1024        ['conv2d_9[0][0]']
#  rmalization)
#
#  leaky_re_lu_9 (LeakyReLU)      (1, 52, 52, 256)     0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (1, 52, 52, 128)     32768       ['leaky_re_lu_9[0][0]']
#
#  batch_normalization_10 (BatchN  (1, 52, 52, 128)    512         ['conv2d_10[0][0]']
#  ormalization)
#
#  leaky_re_lu_10 (LeakyReLU)     (1, 52, 52, 128)     0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (1, 52, 52, 256)     294912      ['leaky_re_lu_10[0][0]']
#
#  batch_normalization_11 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_11[0][0]']
#  ormalization)
#
#  leaky_re_lu_11 (LeakyReLU)     (1, 52, 52, 256)     0           ['batch_normalization_11[0][0]']
#
#  add_3 (Add)                    (1, 52, 52, 256)     0           ['leaky_re_lu_9[0][0]',
#                                                                   'leaky_re_lu_11[0][0]']
#
#  conv2d_12 (Conv2D)             (1, 52, 52, 128)     32768       ['add_3[0][0]']
#
#  batch_normalization_12 (BatchN  (1, 52, 52, 128)    512         ['conv2d_12[0][0]']
#  ormalization)
#
#  leaky_re_lu_12 (LeakyReLU)     (1, 52, 52, 128)     0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (1, 52, 52, 256)     294912      ['leaky_re_lu_12[0][0]']
#
#  batch_normalization_13 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_13[0][0]']
#  ormalization)
#
#  leaky_re_lu_13 (LeakyReLU)     (1, 52, 52, 256)     0           ['batch_normalization_13[0][0]']
#
#  add_4 (Add)                    (1, 52, 52, 256)     0           ['add_3[0][0]',
#                                                                   'leaky_re_lu_13[0][0]']
#
#  conv2d_14 (Conv2D)             (1, 52, 52, 128)     32768       ['add_4[0][0]']
#
#  batch_normalization_14 (BatchN  (1, 52, 52, 128)    512         ['conv2d_14[0][0]']
#  ormalization)
#
#  leaky_re_lu_14 (LeakyReLU)     (1, 52, 52, 128)     0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (1, 52, 52, 256)     294912      ['leaky_re_lu_14[0][0]']
#
#  batch_normalization_15 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_15[0][0]']
#  ormalization)
#
#  leaky_re_lu_15 (LeakyReLU)     (1, 52, 52, 256)     0           ['batch_normalization_15[0][0]']
#
#  add_5 (Add)                    (1, 52, 52, 256)     0           ['add_4[0][0]',
#                                                                   'leaky_re_lu_15[0][0]']
#
#  conv2d_16 (Conv2D)             (1, 52, 52, 128)     32768       ['add_5[0][0]']
#
#  batch_normalization_16 (BatchN  (1, 52, 52, 128)    512         ['conv2d_16[0][0]']
#  ormalization)
#
#  leaky_re_lu_16 (LeakyReLU)     (1, 52, 52, 128)     0           ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (1, 52, 52, 256)     294912      ['leaky_re_lu_16[0][0]']
#
#  batch_normalization_17 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_17[0][0]']
#  ormalization)
#
#  leaky_re_lu_17 (LeakyReLU)     (1, 52, 52, 256)     0           ['batch_normalization_17[0][0]']
#
#  add_6 (Add)                    (1, 52, 52, 256)     0           ['add_5[0][0]',
#                                                                   'leaky_re_lu_17[0][0]']
#
#  conv2d_18 (Conv2D)             (1, 52, 52, 128)     32768       ['add_6[0][0]']
#
#  batch_normalization_18 (BatchN  (1, 52, 52, 128)    512         ['conv2d_18[0][0]']
#  ormalization)
#
#  leaky_re_lu_18 (LeakyReLU)     (1, 52, 52, 128)     0           ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (1, 52, 52, 256)     294912      ['leaky_re_lu_18[0][0]']
#
#  batch_normalization_19 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_19[0][0]']
#  ormalization)
#
#  leaky_re_lu_19 (LeakyReLU)     (1, 52, 52, 256)     0           ['batch_normalization_19[0][0]']
#
#  add_7 (Add)                    (1, 52, 52, 256)     0           ['add_6[0][0]',
#                                                                   'leaky_re_lu_19[0][0]']
#
#  conv2d_20 (Conv2D)             (1, 52, 52, 128)     32768       ['add_7[0][0]']
#
#  batch_normalization_20 (BatchN  (1, 52, 52, 128)    512         ['conv2d_20[0][0]']
#  ormalization)
#
#  leaky_re_lu_20 (LeakyReLU)     (1, 52, 52, 128)     0           ['batch_normalization_20[0][0]']
#
#  conv2d_21 (Conv2D)             (1, 52, 52, 256)     294912      ['leaky_re_lu_20[0][0]']
#
#  batch_normalization_21 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_21[0][0]']
#  ormalization)
#
#  leaky_re_lu_21 (LeakyReLU)     (1, 52, 52, 256)     0           ['batch_normalization_21[0][0]']
#
#  add_8 (Add)                    (1, 52, 52, 256)     0           ['add_7[0][0]',
#                                                                   'leaky_re_lu_21[0][0]']
#
#  conv2d_22 (Conv2D)             (1, 52, 52, 128)     32768       ['add_8[0][0]']
#
#  batch_normalization_22 (BatchN  (1, 52, 52, 128)    512         ['conv2d_22[0][0]']
#  ormalization)
#
#  leaky_re_lu_22 (LeakyReLU)     (1, 52, 52, 128)     0           ['batch_normalization_22[0][0]']
#
#  conv2d_23 (Conv2D)             (1, 52, 52, 256)     294912      ['leaky_re_lu_22[0][0]']
#
#  batch_normalization_23 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_23[0][0]']
#  ormalization)
#
#  leaky_re_lu_23 (LeakyReLU)     (1, 52, 52, 256)     0           ['batch_normalization_23[0][0]']
#
#  add_9 (Add)                    (1, 52, 52, 256)     0           ['add_8[0][0]',
#                                                                   'leaky_re_lu_23[0][0]']
#
#  conv2d_24 (Conv2D)             (1, 52, 52, 128)     32768       ['add_9[0][0]']
#
#  batch_normalization_24 (BatchN  (1, 52, 52, 128)    512         ['conv2d_24[0][0]']
#  ormalization)
#
#  leaky_re_lu_24 (LeakyReLU)     (1, 52, 52, 128)     0           ['batch_normalization_24[0][0]']
#
#  conv2d_25 (Conv2D)             (1, 52, 52, 256)     294912      ['leaky_re_lu_24[0][0]']
#
#  batch_normalization_25 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_25[0][0]']
#  ormalization)
#
#  leaky_re_lu_25 (LeakyReLU)     (1, 52, 52, 256)     0           ['batch_normalization_25[0][0]']
#
#  add_10 (Add)                   (1, 52, 52, 256)     0           ['add_9[0][0]',
#                                                                   'leaky_re_lu_25[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (1, 53, 53, 256)    0           ['add_10[0][0]']
#  D)
#
#  conv2d_26 (Conv2D)             (1, 26, 26, 512)     1179648     ['zero_padding2d_3[0][0]']
#
#  batch_normalization_26 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_26[0][0]']
#  ormalization)
#
#  leaky_re_lu_26 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_26[0][0]']
#
#  conv2d_27 (Conv2D)             (1, 26, 26, 256)     131072      ['leaky_re_lu_26[0][0]']
#
#  batch_normalization_27 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_27[0][0]']
#  ormalization)
#
#  leaky_re_lu_27 (LeakyReLU)     (1, 26, 26, 256)     0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (1, 26, 26, 512)     1179648     ['leaky_re_lu_27[0][0]']
#
#  batch_normalization_28 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_28[0][0]']
#  ormalization)
#
#  leaky_re_lu_28 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_28[0][0]']
#
#  add_11 (Add)                   (1, 26, 26, 512)     0           ['leaky_re_lu_26[0][0]',
#                                                                   'leaky_re_lu_28[0][0]']
#
#  conv2d_29 (Conv2D)             (1, 26, 26, 256)     131072      ['add_11[0][0]']
#
#  batch_normalization_29 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_29[0][0]']
#  ormalization)
#
#  leaky_re_lu_29 (LeakyReLU)     (1, 26, 26, 256)     0           ['batch_normalization_29[0][0]']
#
#  conv2d_30 (Conv2D)             (1, 26, 26, 512)     1179648     ['leaky_re_lu_29[0][0]']
#
#  batch_normalization_30 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_30[0][0]']
#  ormalization)
#
#  leaky_re_lu_30 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_30[0][0]']
#
#  add_12 (Add)                   (1, 26, 26, 512)     0           ['add_11[0][0]',
#                                                                   'leaky_re_lu_30[0][0]']
#
#  conv2d_31 (Conv2D)             (1, 26, 26, 256)     131072      ['add_12[0][0]']
#
#  batch_normalization_31 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_31[0][0]']
#  ormalization)
#
#  leaky_re_lu_31 (LeakyReLU)     (1, 26, 26, 256)     0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (1, 26, 26, 512)     1179648     ['leaky_re_lu_31[0][0]']
#
#  batch_normalization_32 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_32[0][0]']
#  ormalization)
#
#  leaky_re_lu_32 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_32[0][0]']
#
#  add_13 (Add)                   (1, 26, 26, 512)     0           ['add_12[0][0]',
#                                                                   'leaky_re_lu_32[0][0]']
#
#  conv2d_33 (Conv2D)             (1, 26, 26, 256)     131072      ['add_13[0][0]']
#
#  batch_normalization_33 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_33[0][0]']
#  ormalization)
#
#  leaky_re_lu_33 (LeakyReLU)     (1, 26, 26, 256)     0           ['batch_normalization_33[0][0]']
#
#  conv2d_34 (Conv2D)             (1, 26, 26, 512)     1179648     ['leaky_re_lu_33[0][0]']
#
#  batch_normalization_34 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_34[0][0]']
#  ormalization)
#
#  leaky_re_lu_34 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_34[0][0]']
#
#  add_14 (Add)                   (1, 26, 26, 512)     0           ['add_13[0][0]',
#                                                                   'leaky_re_lu_34[0][0]']
#
#  conv2d_35 (Conv2D)             (1, 26, 26, 256)     131072      ['add_14[0][0]']
#
#  batch_normalization_35 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_35[0][0]']
#  ormalization)
#
#  leaky_re_lu_35 (LeakyReLU)     (1, 26, 26, 256)     0           ['batch_normalization_35[0][0]']
#
#  conv2d_36 (Conv2D)             (1, 26, 26, 512)     1179648     ['leaky_re_lu_35[0][0]']
#
#  batch_normalization_36 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_36[0][0]']
#  ormalization)
#
#  leaky_re_lu_36 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_36[0][0]']
#
#  add_15 (Add)                   (1, 26, 26, 512)     0           ['add_14[0][0]',
#                                                                   'leaky_re_lu_36[0][0]']
#
#  conv2d_37 (Conv2D)             (1, 26, 26, 256)     131072      ['add_15[0][0]']
#
#  batch_normalization_37 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_37[0][0]']
#  ormalization)
#
#  leaky_re_lu_37 (LeakyReLU)     (1, 26, 26, 256)     0           ['batch_normalization_37[0][0]']
#
#  conv2d_38 (Conv2D)             (1, 26, 26, 512)     1179648     ['leaky_re_lu_37[0][0]']
#
#  batch_normalization_38 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_38[0][0]']
#  ormalization)
#
#  leaky_re_lu_38 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_38[0][0]']
#
#  add_16 (Add)                   (1, 26, 26, 512)     0           ['add_15[0][0]',
#                                                                   'leaky_re_lu_38[0][0]']
#
#  conv2d_39 (Conv2D)             (1, 26, 26, 256)     131072      ['add_16[0][0]']
#
#  batch_normalization_39 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_39[0][0]']
#  ormalization)
#
#  leaky_re_lu_39 (LeakyReLU)     (1, 26, 26, 256)     0           ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (1, 26, 26, 512)     1179648     ['leaky_re_lu_39[0][0]']
#
#  batch_normalization_40 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_40[0][0]']
#  ormalization)
#
#  leaky_re_lu_40 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_40[0][0]']
#
#  add_17 (Add)                   (1, 26, 26, 512)     0           ['add_16[0][0]',
#                                                                   'leaky_re_lu_40[0][0]']
#
#  conv2d_41 (Conv2D)             (1, 26, 26, 256)     131072      ['add_17[0][0]']
#
#  batch_normalization_41 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_41[0][0]']
#  ormalization)
#
#  leaky_re_lu_41 (LeakyReLU)     (1, 26, 26, 256)     0           ['batch_normalization_41[0][0]']
#
#  conv2d_42 (Conv2D)             (1, 26, 26, 512)     1179648     ['leaky_re_lu_41[0][0]']
#
#  batch_normalization_42 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_42[0][0]']
#  ormalization)
#
#  leaky_re_lu_42 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_42[0][0]']
#
#  add_18 (Add)                   (1, 26, 26, 512)     0           ['add_17[0][0]',
#                                                                   'leaky_re_lu_42[0][0]']
#
#  zero_padding2d_4 (ZeroPadding2  (1, 27, 27, 512)    0           ['add_18[0][0]']
#  D)
#
#  conv2d_43 (Conv2D)             (1, 13, 13, 1024)    4718592     ['zero_padding2d_4[0][0]']
#
#  batch_normalization_43 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_43[0][0]']
#  ormalization)
#
#  leaky_re_lu_43 (LeakyReLU)     (1, 13, 13, 1024)    0           ['batch_normalization_43[0][0]']
#
#  conv2d_44 (Conv2D)             (1, 13, 13, 512)     524288      ['leaky_re_lu_43[0][0]']
#
#  batch_normalization_44 (BatchN  (1, 13, 13, 512)    2048        ['conv2d_44[0][0]']
#  ormalization)
#
#  leaky_re_lu_44 (LeakyReLU)     (1, 13, 13, 512)     0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (1, 13, 13, 1024)    4718592     ['leaky_re_lu_44[0][0]']
#
#  batch_normalization_45 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_45[0][0]']
#  ormalization)
#
#  leaky_re_lu_45 (LeakyReLU)     (1, 13, 13, 1024)    0           ['batch_normalization_45[0][0]']
#
#  add_19 (Add)                   (1, 13, 13, 1024)    0           ['leaky_re_lu_43[0][0]',
#                                                                   'leaky_re_lu_45[0][0]']
#
#  conv2d_46 (Conv2D)             (1, 13, 13, 512)     524288      ['add_19[0][0]']
#
#  batch_normalization_46 (BatchN  (1, 13, 13, 512)    2048        ['conv2d_46[0][0]']
#  ormalization)
#
#  leaky_re_lu_46 (LeakyReLU)     (1, 13, 13, 512)     0           ['batch_normalization_46[0][0]']
#
#  conv2d_47 (Conv2D)             (1, 13, 13, 1024)    4718592     ['leaky_re_lu_46[0][0]']
#
#  batch_normalization_47 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_47[0][0]']
#  ormalization)
#
#  leaky_re_lu_47 (LeakyReLU)     (1, 13, 13, 1024)    0           ['batch_normalization_47[0][0]']
#
#  add_20 (Add)                   (1, 13, 13, 1024)    0           ['add_19[0][0]',
#                                                                   'leaky_re_lu_47[0][0]']
#
#  conv2d_48 (Conv2D)             (1, 13, 13, 512)     524288      ['add_20[0][0]']
#
#  batch_normalization_48 (BatchN  (1, 13, 13, 512)    2048        ['conv2d_48[0][0]']
#  ormalization)
#
#  leaky_re_lu_48 (LeakyReLU)     (1, 13, 13, 512)     0           ['batch_normalization_48[0][0]']
#
#  conv2d_49 (Conv2D)             (1, 13, 13, 1024)    4718592     ['leaky_re_lu_48[0][0]']
#
#  batch_normalization_49 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_49[0][0]']
#  ormalization)
#
#  leaky_re_lu_49 (LeakyReLU)     (1, 13, 13, 1024)    0           ['batch_normalization_49[0][0]']
#
#  add_21 (Add)                   (1, 13, 13, 1024)    0           ['add_20[0][0]',
#                                                                   'leaky_re_lu_49[0][0]']
#
#  conv2d_50 (Conv2D)             (1, 13, 13, 512)     524288      ['add_21[0][0]']
#
#  batch_normalization_50 (BatchN  (1, 13, 13, 512)    2048        ['conv2d_50[0][0]']
#  ormalization)
#
#  leaky_re_lu_50 (LeakyReLU)     (1, 13, 13, 512)     0           ['batch_normalization_50[0][0]']
#
#  conv2d_51 (Conv2D)             (1, 13, 13, 1024)    4718592     ['leaky_re_lu_50[0][0]']
#
#  batch_normalization_51 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_51[0][0]']
#  ormalization)
#
#  leaky_re_lu_51 (LeakyReLU)     (1, 13, 13, 1024)    0           ['batch_normalization_51[0][0]']
#
#  add_22 (Add)                   (1, 13, 13, 1024)    0           ['add_21[0][0]',
#                                                                   'leaky_re_lu_51[0][0]']
#
#  conv2d_52 (Conv2D)             (1, 13, 13, 512)     524288      ['add_22[0][0]']
#
#  batch_normalization_52 (BatchN  (1, 13, 13, 512)    2048        ['conv2d_52[0][0]']
#  ormalization)
#
#  leaky_re_lu_52 (LeakyReLU)     (1, 13, 13, 512)     0           ['batch_normalization_52[0][0]']
#
#  conv2d_53 (Conv2D)             (1, 13, 13, 1024)    4718592     ['leaky_re_lu_52[0][0]']
#
#  batch_normalization_53 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_53[0][0]']
#  ormalization)
#
#  leaky_re_lu_53 (LeakyReLU)     (1, 13, 13, 1024)    0           ['batch_normalization_53[0][0]']
#
#  conv2d_54 (Conv2D)             (1, 13, 13, 512)     524288      ['leaky_re_lu_53[0][0]']
#
#  batch_normalization_54 (BatchN  (1, 13, 13, 512)    2048        ['conv2d_54[0][0]']
#  ormalization)
#
#  leaky_re_lu_54 (LeakyReLU)     (1, 13, 13, 512)     0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (1, 13, 13, 1024)    4718592     ['leaky_re_lu_54[0][0]']
#
#  batch_normalization_55 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_55[0][0]']
#  ormalization)
#
#  leaky_re_lu_55 (LeakyReLU)     (1, 13, 13, 1024)    0           ['batch_normalization_55[0][0]']
#
#  conv2d_56 (Conv2D)             (1, 13, 13, 512)     524288      ['leaky_re_lu_55[0][0]']
#
#  batch_normalization_56 (BatchN  (1, 13, 13, 512)    2048        ['conv2d_56[0][0]']
#  ormalization)
#
#  leaky_re_lu_56 (LeakyReLU)     (1, 13, 13, 512)     0           ['batch_normalization_56[0][0]']
#
#  conv2d_59 (Conv2D)             (1, 13, 13, 256)     131072      ['leaky_re_lu_56[0][0]']
#
#  batch_normalization_58 (BatchN  (1, 13, 13, 256)    1024        ['conv2d_59[0][0]']
#  ormalization)
#
#  leaky_re_lu_58 (LeakyReLU)     (1, 13, 13, 256)     0           ['batch_normalization_58[0][0]']
#
#  up_sampling2d (UpSampling2D)   (1, 26, 26, 256)     0           ['leaky_re_lu_58[0][0]']
#
#  concatenate (Concatenate)      (1, 26, 26, 768)     0           ['up_sampling2d[0][0]',
#                                                                   'add_18[0][0]']
#
#  conv2d_60 (Conv2D)             (1, 26, 26, 256)     196608      ['concatenate[0][0]']
#
#  batch_normalization_59 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_60[0][0]']
#  ormalization)
#
#  leaky_re_lu_59 (LeakyReLU)     (1, 26, 26, 256)     0           ['batch_normalization_59[0][0]']
#
#  conv2d_61 (Conv2D)             (1, 26, 26, 512)     1179648     ['leaky_re_lu_59[0][0]']
#
#  batch_normalization_60 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_61[0][0]']
#  ormalization)
#
#  leaky_re_lu_60 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_60[0][0]']
#
#  conv2d_62 (Conv2D)             (1, 26, 26, 256)     131072      ['leaky_re_lu_60[0][0]']
#
#  batch_normalization_61 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_62[0][0]']
#  ormalization)
#
#  leaky_re_lu_61 (LeakyReLU)     (1, 26, 26, 256)     0           ['batch_normalization_61[0][0]']
#
#  conv2d_63 (Conv2D)             (1, 26, 26, 512)     1179648     ['leaky_re_lu_61[0][0]']
#
#  batch_normalization_62 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_63[0][0]']
#  ormalization)
#
#  leaky_re_lu_62 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_62[0][0]']
#
#  conv2d_64 (Conv2D)             (1, 26, 26, 256)     131072      ['leaky_re_lu_62[0][0]']
#
#  batch_normalization_63 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_64[0][0]']
#  ormalization)
#
#  leaky_re_lu_63 (LeakyReLU)     (1, 26, 26, 256)     0           ['batch_normalization_63[0][0]']
#
#  conv2d_67 (Conv2D)             (1, 26, 26, 128)     32768       ['leaky_re_lu_63[0][0]']
#
#  batch_normalization_65 (BatchN  (1, 26, 26, 128)    512         ['conv2d_67[0][0]']
#  ormalization)
#
#  leaky_re_lu_65 (LeakyReLU)     (1, 26, 26, 128)     0           ['batch_normalization_65[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (1, 52, 52, 128)    0           ['leaky_re_lu_65[0][0]']
#
#  concatenate_1 (Concatenate)    (1, 52, 52, 384)     0           ['up_sampling2d_1[0][0]',
#                                                                   'add_10[0][0]']
#
#  conv2d_68 (Conv2D)             (1, 52, 52, 128)     49152       ['concatenate_1[0][0]']
#
#  batch_normalization_66 (BatchN  (1, 52, 52, 128)    512         ['conv2d_68[0][0]']
#  ormalization)
#
#  leaky_re_lu_66 (LeakyReLU)     (1, 52, 52, 128)     0           ['batch_normalization_66[0][0]']
#
#  conv2d_69 (Conv2D)             (1, 52, 52, 256)     294912      ['leaky_re_lu_66[0][0]']
#
#  batch_normalization_67 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_69[0][0]']
#  ormalization)
#
#  leaky_re_lu_67 (LeakyReLU)     (1, 52, 52, 256)     0           ['batch_normalization_67[0][0]']
#
#  conv2d_70 (Conv2D)             (1, 52, 52, 128)     32768       ['leaky_re_lu_67[0][0]']
#
#  batch_normalization_68 (BatchN  (1, 52, 52, 128)    512         ['conv2d_70[0][0]']
#  ormalization)
#
#  leaky_re_lu_68 (LeakyReLU)     (1, 52, 52, 128)     0           ['batch_normalization_68[0][0]']
#
#  conv2d_71 (Conv2D)             (1, 52, 52, 256)     294912      ['leaky_re_lu_68[0][0]']
#
#  batch_normalization_69 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_71[0][0]']
#  ormalization)
#
#  leaky_re_lu_69 (LeakyReLU)     (1, 52, 52, 256)     0           ['batch_normalization_69[0][0]']
#
#  conv2d_72 (Conv2D)             (1, 52, 52, 128)     32768       ['leaky_re_lu_69[0][0]']
#
#  batch_normalization_70 (BatchN  (1, 52, 52, 128)    512         ['conv2d_72[0][0]']
#  ormalization)
#
#  leaky_re_lu_70 (LeakyReLU)     (1, 52, 52, 128)     0           ['batch_normalization_70[0][0]']
#
#  conv2d_57 (Conv2D)             (1, 13, 13, 1024)    4718592     ['leaky_re_lu_56[0][0]']
#
#  conv2d_65 (Conv2D)             (1, 26, 26, 512)     1179648     ['leaky_re_lu_63[0][0]']
#
#  conv2d_73 (Conv2D)             (1, 52, 52, 256)     294912      ['leaky_re_lu_70[0][0]']
#
#  batch_normalization_57 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_57[0][0]']
#  ormalization)
#
#  batch_normalization_64 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_65[0][0]']
#  ormalization)
#
#  batch_normalization_71 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_73[0][0]']
#  ormalization)
#
#  leaky_re_lu_57 (LeakyReLU)     (1, 13, 13, 1024)    0           ['batch_normalization_57[0][0]']
#
#  leaky_re_lu_64 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_64[0][0]']
#
#  leaky_re_lu_71 (LeakyReLU)     (1, 52, 52, 256)     0           ['batch_normalization_71[0][0]']
#
#  conv2d_58 (Conv2D)             (1, 13, 13, 75)      76875       ['leaky_re_lu_57[0][0]']
#
#  conv2d_66 (Conv2D)             (1, 26, 26, 75)      38475       ['leaky_re_lu_64[0][0]']
#
#  conv2d_74 (Conv2D)             (1, 52, 52, 75)      19275       ['leaky_re_lu_71[0][0]']
#
# ==================================================================================================
# Total params: 61,678,657
# Trainable params: 61,626,049
# Non-trainable params: 52,608
# __________________________________________________________________________________________________

# %%
# save compiled model
new_model.save('yolov3-aerial-compiled.h5')

# %%
model = tf.keras.models.load_model('yolov3-aerial-compiled.h5')
model.summary()
# Out:
# 2023-07-01 18:55:25.458247: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-07-01 18:55:25.586996: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image_input (InputLayer)       [(1, 416, 416, 3)]   0           []
#
#  conv2d (Conv2D)                (1, 416, 416, 32)    864         ['image_input[0][0]']
#
#  batch_normalization (BatchNorm  (1, 416, 416, 32)   128         ['conv2d[0][0]']
#  alization)
#
#  leaky_re_lu (LeakyReLU)        (1, 416, 416, 32)    0           ['batch_normalization[0][0]']
#
#  zero_padding2d (ZeroPadding2D)  (1, 417, 417, 32)   0           ['leaky_re_lu[0][0]']
#
#  conv2d_1 (Conv2D)              (1, 208, 208, 64)    18432       ['zero_padding2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (1, 208, 208, 64)   256         ['conv2d_1[0][0]']
#  rmalization)
#
#  leaky_re_lu_1 (LeakyReLU)      (1, 208, 208, 64)    0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (1, 208, 208, 32)    2048        ['leaky_re_lu_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (1, 208, 208, 32)   128         ['conv2d_2[0][0]']
#  rmalization)
#
#  leaky_re_lu_2 (LeakyReLU)      (1, 208, 208, 32)    0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (1, 208, 208, 64)    18432       ['leaky_re_lu_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (1, 208, 208, 64)   256         ['conv2d_3[0][0]']
#  rmalization)
#
#  leaky_re_lu_3 (LeakyReLU)      (1, 208, 208, 64)    0           ['batch_normalization_3[0][0]']
#
#  add (Add)                      (1, 208, 208, 64)    0           ['leaky_re_lu_1[0][0]',
#                                                                   'leaky_re_lu_3[0][0]']
#
#  zero_padding2d_1 (ZeroPadding2  (1, 209, 209, 64)   0           ['add[0][0]']
#  D)
#
#  conv2d_4 (Conv2D)              (1, 104, 104, 128)   73728       ['zero_padding2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (1, 104, 104, 128)  512         ['conv2d_4[0][0]']
#  rmalization)
#
#  leaky_re_lu_4 (LeakyReLU)      (1, 104, 104, 128)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (1, 104, 104, 64)    8192        ['leaky_re_lu_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (1, 104, 104, 64)   256         ['conv2d_5[0][0]']
#  rmalization)
#
#  leaky_re_lu_5 (LeakyReLU)      (1, 104, 104, 64)    0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (1, 104, 104, 128)   73728       ['leaky_re_lu_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (1, 104, 104, 128)  512         ['conv2d_6[0][0]']
#  rmalization)
#
#  leaky_re_lu_6 (LeakyReLU)      (1, 104, 104, 128)   0           ['batch_normalization_6[0][0]']
#
#  add_1 (Add)                    (1, 104, 104, 128)   0           ['leaky_re_lu_4[0][0]',
#                                                                   'leaky_re_lu_6[0][0]']
#
#  conv2d_7 (Conv2D)              (1, 104, 104, 64)    8192        ['add_1[0][0]']
#
#  batch_normalization_7 (BatchNo  (1, 104, 104, 64)   256         ['conv2d_7[0][0]']
#  rmalization)
#
#  leaky_re_lu_7 (LeakyReLU)      (1, 104, 104, 64)    0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (1, 104, 104, 128)   73728       ['leaky_re_lu_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (1, 104, 104, 128)  512         ['conv2d_8[0][0]']
#  rmalization)
#
#  leaky_re_lu_8 (LeakyReLU)      (1, 104, 104, 128)   0           ['batch_normalization_8[0][0]']
#
#  add_2 (Add)                    (1, 104, 104, 128)   0           ['add_1[0][0]',
#                                                                   'leaky_re_lu_8[0][0]']
#
#  zero_padding2d_2 (ZeroPadding2  (1, 105, 105, 128)  0           ['add_2[0][0]']
#  D)
#
#  conv2d_9 (Conv2D)              (1, 52, 52, 256)     294912      ['zero_padding2d_2[0][0]']
#
#  batch_normalization_9 (BatchNo  (1, 52, 52, 256)    1024        ['conv2d_9[0][0]']
#  rmalization)
#
#  leaky_re_lu_9 (LeakyReLU)      (1, 52, 52, 256)     0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (1, 52, 52, 128)     32768       ['leaky_re_lu_9[0][0]']
#
#  batch_normalization_10 (BatchN  (1, 52, 52, 128)    512         ['conv2d_10[0][0]']
#  ormalization)
#
#  leaky_re_lu_10 (LeakyReLU)     (1, 52, 52, 128)     0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (1, 52, 52, 256)     294912      ['leaky_re_lu_10[0][0]']
#
#  batch_normalization_11 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_11[0][0]']
#  ormalization)
#
#  leaky_re_lu_11 (LeakyReLU)     (1, 52, 52, 256)     0           ['batch_normalization_11[0][0]']
#
#  add_3 (Add)                    (1, 52, 52, 256)     0           ['leaky_re_lu_9[0][0]',
#                                                                   'leaky_re_lu_11[0][0]']
#
#  conv2d_12 (Conv2D)             (1, 52, 52, 128)     32768       ['add_3[0][0]']
#
#  batch_normalization_12 (BatchN  (1, 52, 52, 128)    512         ['conv2d_12[0][0]']
#  ormalization)
#
#  leaky_re_lu_12 (LeakyReLU)     (1, 52, 52, 128)     0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (1, 52, 52, 256)     294912      ['leaky_re_lu_12[0][0]']
#
#  batch_normalization_13 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_13[0][0]']
#  ormalization)
#
#  leaky_re_lu_13 (LeakyReLU)     (1, 52, 52, 256)     0           ['batch_normalization_13[0][0]']
#
#  add_4 (Add)                    (1, 52, 52, 256)     0           ['add_3[0][0]',
#                                                                   'leaky_re_lu_13[0][0]']
#
#  conv2d_14 (Conv2D)             (1, 52, 52, 128)     32768       ['add_4[0][0]']
#
#  batch_normalization_14 (BatchN  (1, 52, 52, 128)    512         ['conv2d_14[0][0]']
#  ormalization)
#
#  leaky_re_lu_14 (LeakyReLU)     (1, 52, 52, 128)     0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (1, 52, 52, 256)     294912      ['leaky_re_lu_14[0][0]']
#
#  batch_normalization_15 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_15[0][0]']
#  ormalization)
#
#  leaky_re_lu_15 (LeakyReLU)     (1, 52, 52, 256)     0           ['batch_normalization_15[0][0]']
#
#  add_5 (Add)                    (1, 52, 52, 256)     0           ['add_4[0][0]',
#                                                                   'leaky_re_lu_15[0][0]']
#
#  conv2d_16 (Conv2D)             (1, 52, 52, 128)     32768       ['add_5[0][0]']
#
#  batch_normalization_16 (BatchN  (1, 52, 52, 128)    512         ['conv2d_16[0][0]']
#  ormalization)
#
#  leaky_re_lu_16 (LeakyReLU)     (1, 52, 52, 128)     0           ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (1, 52, 52, 256)     294912      ['leaky_re_lu_16[0][0]']
#
#  batch_normalization_17 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_17[0][0]']
#  ormalization)
#
#  leaky_re_lu_17 (LeakyReLU)     (1, 52, 52, 256)     0           ['batch_normalization_17[0][0]']
#
#  add_6 (Add)                    (1, 52, 52, 256)     0           ['add_5[0][0]',
#                                                                   'leaky_re_lu_17[0][0]']
#
#  conv2d_18 (Conv2D)             (1, 52, 52, 128)     32768       ['add_6[0][0]']
#
#  batch_normalization_18 (BatchN  (1, 52, 52, 128)    512         ['conv2d_18[0][0]']
#  ormalization)
#
#  leaky_re_lu_18 (LeakyReLU)     (1, 52, 52, 128)     0           ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (1, 52, 52, 256)     294912      ['leaky_re_lu_18[0][0]']
#
#  batch_normalization_19 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_19[0][0]']
#  ormalization)
#
#  leaky_re_lu_19 (LeakyReLU)     (1, 52, 52, 256)     0           ['batch_normalization_19[0][0]']
#
#  add_7 (Add)                    (1, 52, 52, 256)     0           ['add_6[0][0]',
#                                                                   'leaky_re_lu_19[0][0]']
#
#  conv2d_20 (Conv2D)             (1, 52, 52, 128)     32768       ['add_7[0][0]']
#
#  batch_normalization_20 (BatchN  (1, 52, 52, 128)    512         ['conv2d_20[0][0]']
#  ormalization)
#
#  leaky_re_lu_20 (LeakyReLU)     (1, 52, 52, 128)     0           ['batch_normalization_20[0][0]']
#
#  conv2d_21 (Conv2D)             (1, 52, 52, 256)     294912      ['leaky_re_lu_20[0][0]']
#
#  batch_normalization_21 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_21[0][0]']
#  ormalization)
#
#  leaky_re_lu_21 (LeakyReLU)     (1, 52, 52, 256)     0           ['batch_normalization_21[0][0]']
#
#  add_8 (Add)                    (1, 52, 52, 256)     0           ['add_7[0][0]',
#                                                                   'leaky_re_lu_21[0][0]']
#
#  conv2d_22 (Conv2D)             (1, 52, 52, 128)     32768       ['add_8[0][0]']
#
#  batch_normalization_22 (BatchN  (1, 52, 52, 128)    512         ['conv2d_22[0][0]']
#  ormalization)
#
#  leaky_re_lu_22 (LeakyReLU)     (1, 52, 52, 128)     0           ['batch_normalization_22[0][0]']
#
#  conv2d_23 (Conv2D)             (1, 52, 52, 256)     294912      ['leaky_re_lu_22[0][0]']
#
#  batch_normalization_23 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_23[0][0]']
#  ormalization)
#
#  leaky_re_lu_23 (LeakyReLU)     (1, 52, 52, 256)     0           ['batch_normalization_23[0][0]']
#
#  add_9 (Add)                    (1, 52, 52, 256)     0           ['add_8[0][0]',
#                                                                   'leaky_re_lu_23[0][0]']
#
#  conv2d_24 (Conv2D)             (1, 52, 52, 128)     32768       ['add_9[0][0]']
#
#  batch_normalization_24 (BatchN  (1, 52, 52, 128)    512         ['conv2d_24[0][0]']
#  ormalization)
#
#  leaky_re_lu_24 (LeakyReLU)     (1, 52, 52, 128)     0           ['batch_normalization_24[0][0]']
#
#  conv2d_25 (Conv2D)             (1, 52, 52, 256)     294912      ['leaky_re_lu_24[0][0]']
#
#  batch_normalization_25 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_25[0][0]']
#  ormalization)
#
#  leaky_re_lu_25 (LeakyReLU)     (1, 52, 52, 256)     0           ['batch_normalization_25[0][0]']
#
#  add_10 (Add)                   (1, 52, 52, 256)     0           ['add_9[0][0]',
#                                                                   'leaky_re_lu_25[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (1, 53, 53, 256)    0           ['add_10[0][0]']
#  D)
#
#  conv2d_26 (Conv2D)             (1, 26, 26, 512)     1179648     ['zero_padding2d_3[0][0]']
#
#  batch_normalization_26 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_26[0][0]']
#  ormalization)
#
#  leaky_re_lu_26 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_26[0][0]']
#
#  conv2d_27 (Conv2D)             (1, 26, 26, 256)     131072      ['leaky_re_lu_26[0][0]']
#
#  batch_normalization_27 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_27[0][0]']
#  ormalization)
#
#  leaky_re_lu_27 (LeakyReLU)     (1, 26, 26, 256)     0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (1, 26, 26, 512)     1179648     ['leaky_re_lu_27[0][0]']
#
#  batch_normalization_28 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_28[0][0]']
#  ormalization)
#
#  leaky_re_lu_28 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_28[0][0]']
#
#  add_11 (Add)                   (1, 26, 26, 512)     0           ['leaky_re_lu_26[0][0]',
#                                                                   'leaky_re_lu_28[0][0]']
#
#  conv2d_29 (Conv2D)             (1, 26, 26, 256)     131072      ['add_11[0][0]']
#
#  batch_normalization_29 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_29[0][0]']
#  ormalization)
#
#  leaky_re_lu_29 (LeakyReLU)     (1, 26, 26, 256)     0           ['batch_normalization_29[0][0]']
#
#  conv2d_30 (Conv2D)             (1, 26, 26, 512)     1179648     ['leaky_re_lu_29[0][0]']
#
#  batch_normalization_30 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_30[0][0]']
#  ormalization)
#
#  leaky_re_lu_30 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_30[0][0]']
#
#  add_12 (Add)                   (1, 26, 26, 512)     0           ['add_11[0][0]',
#                                                                   'leaky_re_lu_30[0][0]']
#
#  conv2d_31 (Conv2D)             (1, 26, 26, 256)     131072      ['add_12[0][0]']
#
#  batch_normalization_31 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_31[0][0]']
#  ormalization)
#
#  leaky_re_lu_31 (LeakyReLU)     (1, 26, 26, 256)     0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (1, 26, 26, 512)     1179648     ['leaky_re_lu_31[0][0]']
#
#  batch_normalization_32 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_32[0][0]']
#  ormalization)
#
#  leaky_re_lu_32 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_32[0][0]']
#
#  add_13 (Add)                   (1, 26, 26, 512)     0           ['add_12[0][0]',
#                                                                   'leaky_re_lu_32[0][0]']
#
#  conv2d_33 (Conv2D)             (1, 26, 26, 256)     131072      ['add_13[0][0]']
#
#  batch_normalization_33 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_33[0][0]']
#  ormalization)
#
#  leaky_re_lu_33 (LeakyReLU)     (1, 26, 26, 256)     0           ['batch_normalization_33[0][0]']
#
#  conv2d_34 (Conv2D)             (1, 26, 26, 512)     1179648     ['leaky_re_lu_33[0][0]']
#
#  batch_normalization_34 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_34[0][0]']
#  ormalization)
#
#  leaky_re_lu_34 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_34[0][0]']
#
#  add_14 (Add)                   (1, 26, 26, 512)     0           ['add_13[0][0]',
#                                                                   'leaky_re_lu_34[0][0]']
#
#  conv2d_35 (Conv2D)             (1, 26, 26, 256)     131072      ['add_14[0][0]']
#
#  batch_normalization_35 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_35[0][0]']
#  ormalization)
#
#  leaky_re_lu_35 (LeakyReLU)     (1, 26, 26, 256)     0           ['batch_normalization_35[0][0]']
#
#  conv2d_36 (Conv2D)             (1, 26, 26, 512)     1179648     ['leaky_re_lu_35[0][0]']
#
#  batch_normalization_36 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_36[0][0]']
#  ormalization)
#
#  leaky_re_lu_36 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_36[0][0]']
#
#  add_15 (Add)                   (1, 26, 26, 512)     0           ['add_14[0][0]',
#                                                                   'leaky_re_lu_36[0][0]']
#
#  conv2d_37 (Conv2D)             (1, 26, 26, 256)     131072      ['add_15[0][0]']
#
#  batch_normalization_37 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_37[0][0]']
#  ormalization)
#
#  leaky_re_lu_37 (LeakyReLU)     (1, 26, 26, 256)     0           ['batch_normalization_37[0][0]']
#
#  conv2d_38 (Conv2D)             (1, 26, 26, 512)     1179648     ['leaky_re_lu_37[0][0]']
#
#  batch_normalization_38 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_38[0][0]']
#  ormalization)
#
#  leaky_re_lu_38 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_38[0][0]']
#
#  add_16 (Add)                   (1, 26, 26, 512)     0           ['add_15[0][0]',
#                                                                   'leaky_re_lu_38[0][0]']
#
#  conv2d_39 (Conv2D)             (1, 26, 26, 256)     131072      ['add_16[0][0]']
#
#  batch_normalization_39 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_39[0][0]']
#  ormalization)
#
#  leaky_re_lu_39 (LeakyReLU)     (1, 26, 26, 256)     0           ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (1, 26, 26, 512)     1179648     ['leaky_re_lu_39[0][0]']
#
#  batch_normalization_40 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_40[0][0]']
#  ormalization)
#
#  leaky_re_lu_40 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_40[0][0]']
#
#  add_17 (Add)                   (1, 26, 26, 512)     0           ['add_16[0][0]',
#                                                                   'leaky_re_lu_40[0][0]']
#
#  conv2d_41 (Conv2D)             (1, 26, 26, 256)     131072      ['add_17[0][0]']
#
#  batch_normalization_41 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_41[0][0]']
#  ormalization)
#
#  leaky_re_lu_41 (LeakyReLU)     (1, 26, 26, 256)     0           ['batch_normalization_41[0][0]']
#
#  conv2d_42 (Conv2D)             (1, 26, 26, 512)     1179648     ['leaky_re_lu_41[0][0]']
#
#  batch_normalization_42 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_42[0][0]']
#  ormalization)
#
#  leaky_re_lu_42 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_42[0][0]']
#
#  add_18 (Add)                   (1, 26, 26, 512)     0           ['add_17[0][0]',
#                                                                   'leaky_re_lu_42[0][0]']
#
#  zero_padding2d_4 (ZeroPadding2  (1, 27, 27, 512)    0           ['add_18[0][0]']
#  D)
#
#  conv2d_43 (Conv2D)             (1, 13, 13, 1024)    4718592     ['zero_padding2d_4[0][0]']
#
#  batch_normalization_43 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_43[0][0]']
#  ormalization)
#
#  leaky_re_lu_43 (LeakyReLU)     (1, 13, 13, 1024)    0           ['batch_normalization_43[0][0]']
#
#  conv2d_44 (Conv2D)             (1, 13, 13, 512)     524288      ['leaky_re_lu_43[0][0]']
#
#  batch_normalization_44 (BatchN  (1, 13, 13, 512)    2048        ['conv2d_44[0][0]']
#  ormalization)
#
#  leaky_re_lu_44 (LeakyReLU)     (1, 13, 13, 512)     0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (1, 13, 13, 1024)    4718592     ['leaky_re_lu_44[0][0]']
#
#  batch_normalization_45 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_45[0][0]']
#  ormalization)
#
#  leaky_re_lu_45 (LeakyReLU)     (1, 13, 13, 1024)    0           ['batch_normalization_45[0][0]']
#
#  add_19 (Add)                   (1, 13, 13, 1024)    0           ['leaky_re_lu_43[0][0]',
#                                                                   'leaky_re_lu_45[0][0]']
#
#  conv2d_46 (Conv2D)             (1, 13, 13, 512)     524288      ['add_19[0][0]']
#
#  batch_normalization_46 (BatchN  (1, 13, 13, 512)    2048        ['conv2d_46[0][0]']
#  ormalization)
#
#  leaky_re_lu_46 (LeakyReLU)     (1, 13, 13, 512)     0           ['batch_normalization_46[0][0]']
#
#  conv2d_47 (Conv2D)             (1, 13, 13, 1024)    4718592     ['leaky_re_lu_46[0][0]']
#
#  batch_normalization_47 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_47[0][0]']
#  ormalization)
#
#  leaky_re_lu_47 (LeakyReLU)     (1, 13, 13, 1024)    0           ['batch_normalization_47[0][0]']
#
#  add_20 (Add)                   (1, 13, 13, 1024)    0           ['add_19[0][0]',
#                                                                   'leaky_re_lu_47[0][0]']
#
#  conv2d_48 (Conv2D)             (1, 13, 13, 512)     524288      ['add_20[0][0]']
#
#  batch_normalization_48 (BatchN  (1, 13, 13, 512)    2048        ['conv2d_48[0][0]']
#  ormalization)
#
#  leaky_re_lu_48 (LeakyReLU)     (1, 13, 13, 512)     0           ['batch_normalization_48[0][0]']
#
#  conv2d_49 (Conv2D)             (1, 13, 13, 1024)    4718592     ['leaky_re_lu_48[0][0]']
#
#  batch_normalization_49 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_49[0][0]']
#  ormalization)
#
#  leaky_re_lu_49 (LeakyReLU)     (1, 13, 13, 1024)    0           ['batch_normalization_49[0][0]']
#
#  add_21 (Add)                   (1, 13, 13, 1024)    0           ['add_20[0][0]',
#                                                                   'leaky_re_lu_49[0][0]']
#
#  conv2d_50 (Conv2D)             (1, 13, 13, 512)     524288      ['add_21[0][0]']
#
#  batch_normalization_50 (BatchN  (1, 13, 13, 512)    2048        ['conv2d_50[0][0]']
#  ormalization)
#
#  leaky_re_lu_50 (LeakyReLU)     (1, 13, 13, 512)     0           ['batch_normalization_50[0][0]']
#
#  conv2d_51 (Conv2D)             (1, 13, 13, 1024)    4718592     ['leaky_re_lu_50[0][0]']
#
#  batch_normalization_51 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_51[0][0]']
#  ormalization)
#
#  leaky_re_lu_51 (LeakyReLU)     (1, 13, 13, 1024)    0           ['batch_normalization_51[0][0]']
#
#  add_22 (Add)                   (1, 13, 13, 1024)    0           ['add_21[0][0]',
#                                                                   'leaky_re_lu_51[0][0]']
#
#  conv2d_52 (Conv2D)             (1, 13, 13, 512)     524288      ['add_22[0][0]']
#
#  batch_normalization_52 (BatchN  (1, 13, 13, 512)    2048        ['conv2d_52[0][0]']
#  ormalization)
#
#  leaky_re_lu_52 (LeakyReLU)     (1, 13, 13, 512)     0           ['batch_normalization_52[0][0]']
#
#  conv2d_53 (Conv2D)             (1, 13, 13, 1024)    4718592     ['leaky_re_lu_52[0][0]']
#
#  batch_normalization_53 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_53[0][0]']
#  ormalization)
#
#  leaky_re_lu_53 (LeakyReLU)     (1, 13, 13, 1024)    0           ['batch_normalization_53[0][0]']
#
#  conv2d_54 (Conv2D)             (1, 13, 13, 512)     524288      ['leaky_re_lu_53[0][0]']
#
#  batch_normalization_54 (BatchN  (1, 13, 13, 512)    2048        ['conv2d_54[0][0]']
#  ormalization)
#
#  leaky_re_lu_54 (LeakyReLU)     (1, 13, 13, 512)     0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (1, 13, 13, 1024)    4718592     ['leaky_re_lu_54[0][0]']
#
#  batch_normalization_55 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_55[0][0]']
#  ormalization)
#
#  leaky_re_lu_55 (LeakyReLU)     (1, 13, 13, 1024)    0           ['batch_normalization_55[0][0]']
#
#  conv2d_56 (Conv2D)             (1, 13, 13, 512)     524288      ['leaky_re_lu_55[0][0]']
#
#  batch_normalization_56 (BatchN  (1, 13, 13, 512)    2048        ['conv2d_56[0][0]']
#  ormalization)
#
#  leaky_re_lu_56 (LeakyReLU)     (1, 13, 13, 512)     0           ['batch_normalization_56[0][0]']
#
#  conv2d_59 (Conv2D)             (1, 13, 13, 256)     131072      ['leaky_re_lu_56[0][0]']
#
#  batch_normalization_58 (BatchN  (1, 13, 13, 256)    1024        ['conv2d_59[0][0]']
#  ormalization)
#
#  leaky_re_lu_58 (LeakyReLU)     (1, 13, 13, 256)     0           ['batch_normalization_58[0][0]']
#
#  up_sampling2d (UpSampling2D)   (1, 26, 26, 256)     0           ['leaky_re_lu_58[0][0]']
#
#  concatenate (Concatenate)      (1, 26, 26, 768)     0           ['up_sampling2d[0][0]',
#                                                                   'add_18[0][0]']
#
#  conv2d_60 (Conv2D)             (1, 26, 26, 256)     196608      ['concatenate[0][0]']
#
#  batch_normalization_59 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_60[0][0]']
#  ormalization)
#
#  leaky_re_lu_59 (LeakyReLU)     (1, 26, 26, 256)     0           ['batch_normalization_59[0][0]']
#
#  conv2d_61 (Conv2D)             (1, 26, 26, 512)     1179648     ['leaky_re_lu_59[0][0]']
#
#  batch_normalization_60 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_61[0][0]']
#  ormalization)
#
#  leaky_re_lu_60 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_60[0][0]']
#
#  conv2d_62 (Conv2D)             (1, 26, 26, 256)     131072      ['leaky_re_lu_60[0][0]']
#
#  batch_normalization_61 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_62[0][0]']
#  ormalization)
#
#  leaky_re_lu_61 (LeakyReLU)     (1, 26, 26, 256)     0           ['batch_normalization_61[0][0]']
#
#  conv2d_63 (Conv2D)             (1, 26, 26, 512)     1179648     ['leaky_re_lu_61[0][0]']
#
#  batch_normalization_62 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_63[0][0]']
#  ormalization)
#
#  leaky_re_lu_62 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_62[0][0]']
#
#  conv2d_64 (Conv2D)             (1, 26, 26, 256)     131072      ['leaky_re_lu_62[0][0]']
#
#  batch_normalization_63 (BatchN  (1, 26, 26, 256)    1024        ['conv2d_64[0][0]']
#  ormalization)
#
#  leaky_re_lu_63 (LeakyReLU)     (1, 26, 26, 256)     0           ['batch_normalization_63[0][0]']
#
#  conv2d_67 (Conv2D)             (1, 26, 26, 128)     32768       ['leaky_re_lu_63[0][0]']
#
#  batch_normalization_65 (BatchN  (1, 26, 26, 128)    512         ['conv2d_67[0][0]']
#  ormalization)
#
#  leaky_re_lu_65 (LeakyReLU)     (1, 26, 26, 128)     0           ['batch_normalization_65[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (1, 52, 52, 128)    0           ['leaky_re_lu_65[0][0]']
#
#  concatenate_1 (Concatenate)    (1, 52, 52, 384)     0           ['up_sampling2d_1[0][0]',
#                                                                   'add_10[0][0]']
#
#  conv2d_68 (Conv2D)             (1, 52, 52, 128)     49152       ['concatenate_1[0][0]']
#
#  batch_normalization_66 (BatchN  (1, 52, 52, 128)    512         ['conv2d_68[0][0]']
#  ormalization)
#
#  leaky_re_lu_66 (LeakyReLU)     (1, 52, 52, 128)     0           ['batch_normalization_66[0][0]']
#
#  conv2d_69 (Conv2D)             (1, 52, 52, 256)     294912      ['leaky_re_lu_66[0][0]']
#
#  batch_normalization_67 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_69[0][0]']
#  ormalization)
#
#  leaky_re_lu_67 (LeakyReLU)     (1, 52, 52, 256)     0           ['batch_normalization_67[0][0]']
#
#  conv2d_70 (Conv2D)             (1, 52, 52, 128)     32768       ['leaky_re_lu_67[0][0]']
#
#  batch_normalization_68 (BatchN  (1, 52, 52, 128)    512         ['conv2d_70[0][0]']
#  ormalization)
#
#  leaky_re_lu_68 (LeakyReLU)     (1, 52, 52, 128)     0           ['batch_normalization_68[0][0]']
#
#  conv2d_71 (Conv2D)             (1, 52, 52, 256)     294912      ['leaky_re_lu_68[0][0]']
#
#  batch_normalization_69 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_71[0][0]']
#  ormalization)
#
#  leaky_re_lu_69 (LeakyReLU)     (1, 52, 52, 256)     0           ['batch_normalization_69[0][0]']
#
#  conv2d_72 (Conv2D)             (1, 52, 52, 128)     32768       ['leaky_re_lu_69[0][0]']
#
#  batch_normalization_70 (BatchN  (1, 52, 52, 128)    512         ['conv2d_72[0][0]']
#  ormalization)
#
#  leaky_re_lu_70 (LeakyReLU)     (1, 52, 52, 128)     0           ['batch_normalization_70[0][0]']
#
#  conv2d_57 (Conv2D)             (1, 13, 13, 1024)    4718592     ['leaky_re_lu_56[0][0]']
#
#  conv2d_65 (Conv2D)             (1, 26, 26, 512)     1179648     ['leaky_re_lu_63[0][0]']
#
#  conv2d_73 (Conv2D)             (1, 52, 52, 256)     294912      ['leaky_re_lu_70[0][0]']
#
#  batch_normalization_57 (BatchN  (1, 13, 13, 1024)   4096        ['conv2d_57[0][0]']
#  ormalization)
#
#  batch_normalization_64 (BatchN  (1, 26, 26, 512)    2048        ['conv2d_65[0][0]']
#  ormalization)
#
#  batch_normalization_71 (BatchN  (1, 52, 52, 256)    1024        ['conv2d_73[0][0]']
#  ormalization)
#
#  leaky_re_lu_57 (LeakyReLU)     (1, 13, 13, 1024)    0           ['batch_normalization_57[0][0]']
#
#  leaky_re_lu_64 (LeakyReLU)     (1, 26, 26, 512)     0           ['batch_normalization_64[0][0]']
#
#  leaky_re_lu_71 (LeakyReLU)     (1, 52, 52, 256)     0           ['batch_normalization_71[0][0]']
#
#  conv2d_58 (Conv2D)             (1, 13, 13, 75)      76875       ['leaky_re_lu_57[0][0]']
#
#  conv2d_66 (Conv2D)             (1, 26, 26, 75)      38475       ['leaky_re_lu_64[0][0]']
#
#  conv2d_74 (Conv2D)             (1, 52, 52, 75)      19275       ['leaky_re_lu_71[0][0]']
#
# ==================================================================================================
# Total params: 61,678,657
# Trainable params: 61,626,049
# Non-trainable params: 52,608
# __________________________________________________________________________________________________

# %% [markdown]
# ##### We can now convert the model to onnx format
#
# It is worth noting that, while onnx tends to be a good intermediate format for various applications, not all targets support the same set of operations. For instance, tensorrt does not support a 'tf_half_pixel_for_nn' operation. We can account for this by setting the target to 'tensorrt' (tf2onnx will automatically replace unsupported operations with their nearest equivalents). It is important to account for this when converting the model to your target platform.

# %%
tf2onnx.convert.from_keras(model, output_path="yolov3-aerial.onnx", target="tensorrt")
# Out:
# 2023-07-01 18:55:38.774940: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-07-01 18:55:38.774986: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2023-07-01 18:55:38.775103: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-07-01 18:55:38.775471: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-07-01 18:55:38.775484: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-07-01 18:55:41.143506: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-07-01 18:55:41.143558: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2023-07-01 18:55:41.143656: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-07-01 18:55:41.144031: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-07-01 18:55:41.144047: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# ##### We can now test the model is working as expected

# %%
import onnxruntime as onnx_rt
import numpy as np

sess = onnx_rt.InferenceSession("yolov3-aerial.onnx", providers=["CUDAExecutionProvider"])
# Out:
# 2023-05-19 19:26:28.793807100 [W:onnxruntime:Default, onnxruntime_pybind_state.cc:541 CreateExecutionProviderInstance] Failed to create CUDAExecutionProvider. Please reference https://onnxruntime.ai/docs/reference/execution-providers/CUDA-ExecutionProvider.html#requirements to ensure all dependencies are met.
# 2023-05-19 19:26:28.975900707 [W:onnxruntime:Default, upsamplebase.h:102 UpsampleBase] `tf_half_pixel_for_nn` is deprecated since opset 13, yet this opset 13 model uses the deprecated attribute
# 2023-05-19 19:26:28.975921657 [W:onnxruntime:Default, upsamplebase.h:102 UpsampleBase] `tf_half_pixel_for_nn` is deprecated since opset 13, yet this opset 13 model uses the deprecated attribute

# %%
# %%timeit

outputs = sess.run(None, {"image_input": np.random.rand(1, 416, 416, 3).astype(np.float32)})
# Out:
# 129 ms ± 1.8 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
